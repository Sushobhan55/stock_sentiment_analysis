# %%
import yfinance as yf

# %%
msft = yf.Ticker("MSFT")

# %%
msft.info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 181000,
# ...

# %%
data = yf.download("SPY AAPL", start="2017-01-01", end="2017-04-30")
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
data
# Out:
#             Adj Close                  Close                   High  \
#                  AAPL         SPY       AAPL         SPY       AAPL
# Date
# 2017-01-03  27.372360  206.871765  29.037500  225.240005  29.082500
# 2017-01-04  27.341726  208.102493  29.004999  226.580002  29.127501
# 2017-01-05  27.480770  207.937164  29.152500  226.399994  29.215000
# 2017-01-06  27.787136  208.681122  29.477501  227.210007  29.540001
# 2017-01-09  28.041647  207.992279  29.747499  226.460007  29.857500
# ...               ...         ...        ...         ...        ...
# 2017-04-24  33.997524  218.776550  35.910000  237.169998  35.987499
# 2017-04-25  34.208176  220.049484  36.132500  238.550003  36.224998
# 2017-04-26  34.006992  219.911133  35.919998  238.399994  36.150002
# 2017-04-27  34.033024  220.095673  35.947498  238.600006  36.040001
# 2017-04-28  33.999893  219.615952  35.912498  238.080002  36.075001
#
#                               Low                   Open              \
# ...
